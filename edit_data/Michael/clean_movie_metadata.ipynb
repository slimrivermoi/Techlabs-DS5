# %%
import numpy as np
import pandas as pd
import ast

# %%
unchanged_df = pd.read_csv('data/movies_metadata.csv')
# Out:
# C:\Users\michi\AppData\Local\Temp\ipykernel_17828\2759666113.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   unchanged_df = pd.read_csv('data/movies_metadata.csv')

# %%
unchanged_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
cleaned_df = pd.read_csv('data/movies_metadata.csv')
# Out:
# C:\Users\michi\AppData\Local\Temp\ipykernel_17828\23010306.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   cleaned_df = pd.read_csv('data/movies_metadata.csv')

# %%
#filter where adult values aren't True or False, these rows have completely wrong values in the columns 
filt = ((cleaned_df["adult"] != "False") & (cleaned_df["adult"] != "True"))
cleaned_df.loc[filt]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %%
#remove these
cleaned_df.drop(index = [19730, 29503, 35587], inplace = True)

# %%
cleaned_df.id.value_counts()
# Out:
# id
# 141971    3
# 5511      2
# 132641    2
# 10991     2
# 168538    2
#          ..
# 55135     1
# 15877     1
# 72272     1
# 1549      1
# 461257    1
# Name: count, Length: 45433, dtype: int64

# %%
#cleans dataframe of exact duplicate rows
cleaned_df = cleaned_df.astype(str).drop_duplicates()

# %%
#same function just to be safe
cleaned_df.drop_duplicates(inplace = True)

# %%
cleaned_df.id.value_counts()
# Out:
# id
# 15028     2
# 22649     2
# 84198     2
# 14788     2
# 109962    2
#          ..
# 27004     1
# 10870     1
# 54117     1
# 4180      1
# 461257    1
# Name: count, Length: 45433, dtype: int64

# %% [markdown]
# *---------------------------------DELETE ALL ROWS WITH SAME ID AND HIGHER POPULARITY THESE LINES DONT HAVE TO BE RERUN THEY WHERE NEEDED TO FIND LOWEST POPULARITY----------------------------------*

# %%
filt15028 = (cleaned_df["id"] == "15028")
cleaned_df.loc[filt15028] #33743 lower popularity, checked
# Out:
#        adult belongs_to_collection    budget  \
# 5130   False                   nan  26000000
# 33743  False                   nan  26000000
#
#                                                   genres homepage     id  \
# 5130   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...      nan  15028
# 33743  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...      nan  15028
#
#          imdb_id original_language original_title  \
# 5130   tt0157472                en  Clockstoppers
# 33743  tt0157472                en  Clockstoppers
#
#                                                 overview  ... release_date  \
# 5130   Until now, Zak Gibbs' greatest challenge has b...  ...   2002-03-17
# 33743  Until now, Zak Gibbs' greatest challenge has b...  ...   2002-03-17
#
#           revenue runtime                                   spoken_languages  \
# 5130   38793283.0    94.0  [{'iso_639_1': 'cs', 'name': 'Český'}, {'iso_6...
# ...

# %%
filt22649 = (cleaned_df["id"] == "22649")
cleaned_df.loc[filt22649] #949, checked
# Out:
#        adult belongs_to_collection budget  \
# 949    False                   nan      4
# 15074  False                   nan      4
#
#                                                   genres homepage     id  \
# 949    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      nan  22649
# 15074  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      nan  22649
#
#          imdb_id original_language      original_title  \
# 949    tt0022879                en  A Farewell to Arms
# 15074  tt0022879                en  A Farewell to Arms
#
#                                                 overview  ... release_date  \
# 949    British nurse Catherine Barkley (Helen Hayes) ...  ...   1932-12-08
# 15074  British nurse Catherine Barkley (Helen Hayes) ...  ...   1932-12-08
#
#       revenue runtime                          spoken_languages    status  \
# 949      25.0    89.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %%
filt84198 = (cleaned_df["id"] == "84198")
cleaned_df.loc[filt84198] #2564, checked
# Out:
#        adult belongs_to_collection budget  \
# 2564   False                   nan      0
# 21116  False                   nan      0
#
#                                     genres homepage     id    imdb_id  \
# 2564   [{'id': 99, 'name': 'Documentary'}]      nan  84198  tt1736049
# 21116  [{'id': 99, 'name': 'Documentary'}]      nan  84198  tt1736049
#
#       original_language        original_title  \
# 2564                 en  A Place at the Table
# 21116                en  A Place at the Table
#
#                                                 overview  ... release_date  \
# 2564   Using personal stories, this powerful document...  ...   2012-03-22
# 21116  Using personal stories, this powerful document...  ...   2012-03-22
#
#       revenue runtime                          spoken_languages    status  \
# 2564      0.0    84.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 21116     0.0    84.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
# ...

# %%
filt14788 = (cleaned_df["id"] == "14788")
cleaned_df.loc[filt14788] #12066, checked
# Out:
#        adult belongs_to_collection   budget  \
# 10419  False                   nan  1600000
# 12066  False                   nan  1600000
#
#                                                   genres  \
# 10419  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 12066  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                             homepage     id    imdb_id original_language  \
# 10419  http://www.bubblethefilm.com/  14788  tt0454792                en
# 12066  http://www.bubblethefilm.com/  14788  tt0454792                en
#
#       original_title                                           overview  ...  \
# 10419         Bubble  Set against the backdrop of a decaying Midwest...  ...
# 12066         Bubble  Set against the backdrop of a decaying Midwest...  ...
#
#       release_date revenue runtime                          spoken_languages  \
# 10419   2005-09-03     0.0    73.0  [{'iso_639_1': 'en', 'name': 'English'}]
# ...

# %%
filt109962 = (cleaned_df["id"] == "109962")
cleaned_df.loc[filt109962] #20899, checked
# Out:
#        adult belongs_to_collection budget                         genres  \
# 5710   False                   nan      0  [{'id': 18, 'name': 'Drama'}]
# 20899  False                   nan      0  [{'id': 18, 'name': 'Drama'}]
#
#       homepage      id    imdb_id original_language   original_title  \
# 5710       nan  109962  tt0082992                en  Rich and Famous
# 20899      nan  109962  tt0082992                en  Rich and Famous
#
#                                                 overview  ... release_date  \
# 5710   Two literary women compete for 20 years: one w...  ...   1981-09-23
# 20899  Two literary women compete for 20 years: one w...  ...   1981-09-23
#
#       revenue runtime                          spoken_languages    status  \
# 5710      0.0   115.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 20899     0.0   115.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline            title  \
# ...

# %%
filt12600 = (cleaned_df["id"] == "12600")
cleaned_df.loc[filt12600] #44826, checked
# Out:
#        adult                              belongs_to_collection budget  \
# 5535   False  {'id': 34055, 'name': 'Pokémon Collection', 'p...      0
# 44826  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...      0
#
#                                                   genres  \
# 5535   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 44826  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                                 homepage     id    imdb_id  \
# 5535   http://www.pokemon.com/us/movies/movie-pokemon...  12600  tt0287635
# 44826  http://www.pokemon.com/us/movies/movie-pokemon...  12600  tt0287635
#
#       original_language                  original_title  \
# 5535                 ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 44826                ja  劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
#
#                                                 overview  ... release_date  \
# 5535   All your favorite Pokémon characters are back,...  ...   2001-07-06
# ...

# %%
filt10991 = (cleaned_df["id"] == "10991")
cleaned_df.loc[filt10991] #44821, checked
# Out:
#        adult                              belongs_to_collection    budget  \
# 4114   False  {'id': 34055, 'name': 'Pokémon Collection', 'p...  16000000
# 44821  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...  16000000
#
#                                                   genres  \
# 4114   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 44821  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                 homepage     id    imdb_id original_language  \
# 4114   http://movies.warnerbros.com/pk3/  10991  tt0235679                ja
# 44821  http://movies.warnerbros.com/pk3/  10991  tt0235679                ja
#
#              original_title  \
# 4114   Pokémon 3: The Movie
# 44821  Pokémon 3: The Movie
#
#                                                 overview  ... release_date  \
# 4114   When Molly Hale's sadness of her father's disa...  ...   2000-07-08
# 44821  When Molly Hale's sadness of her father's disa...  ...   2000-07-08
#
# ...

# %%
filt132641 = (cleaned_df["id"] == "132641")
cleaned_df.loc[filt132641] #838, checked
# Out:
#        adult belongs_to_collection budget                         genres  \
# 838    False                   nan      0  [{'id': 18, 'name': 'Drama'}]
# 30001  False                   nan      0  [{'id': 18, 'name': 'Drama'}]
#
#       homepage      id    imdb_id original_language original_title  \
# 838        nan  132641  tt0046468                ja          Tsuma
# 30001      nan  132641  tt0046468                ja          Tsuma
#
#                                                 overview  ... release_date  \
# 838    Ten years into a marriage, the wife is disappo...  ...   1953-04-29
# 30001  Ten years into a marriage, the wife is disappo...  ...   1953-04-29
#
#       revenue runtime                      spoken_languages    status tagline  \
# 838       0.0    89.0  [{'iso_639_1': 'ja', 'name': '日本語'}]  Released     nan
# 30001     0.0    89.0  [{'iso_639_1': 'ja', 'name': '日本語'}]  Released     nan
#
#       title  video vote_average vote_count
# ...

# %%
filt77221 = (cleaned_df["id"] == "77221")
cleaned_df.loc[filt77221] #20843, checked
# Out:
#        adult belongs_to_collection    budget  \
# 11155  False                   nan  40000000
# 20843  False                   nan  40000000
#
#                                                   genres homepage     id  \
# 11155  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...      nan  77221
# 20843  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...      nan  77221
#
#          imdb_id original_language original_title  \
# 11155  tt1701210                en     Black Gold
# 20843  tt1701210                en     Black Gold
#
#                                                 overview  ... release_date  \
# 11155  On the Arabian Peninsula in the 1930s, two war...  ...   2011-12-21
# 20843  On the Arabian Peninsula in the 1930s, two war...  ...   2011-12-21
#
#          revenue runtime                          spoken_languages    status  \
# 11155  5446000.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %%
filt69234 = (cleaned_df["id"] == "69234")
cleaned_df.loc[filt69234] #26625, checked
# Out:
#        adult belongs_to_collection    budget  \
# 9576   False                   nan  10000000
# 26625  False                   nan  10000000
#
#                                                   genres homepage     id  \
# 9576   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      nan  69234
# 26625  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      nan  69234
#
#          imdb_id original_language            original_title  \
# 9576   tt0100361                en  The Phantom of the Opera
# 26625  tt0100361                en  The Phantom of the Opera
#
#                                                 overview  ... release_date  \
# 9576   Count de Chagnie has discovered Christine's si...  ...   1990-03-18
# 26625  Count de Chagnie has discovered Christine's si...  ...   1990-03-18
#
#       revenue runtime                                   spoken_languages  \
# 9576      0.0   168.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...

# %%
filt13209 = (cleaned_df["id"] == "13209")
cleaned_df.loc[filt13209] #11342, checked
# Out:
#        adult belongs_to_collection budget  \
# 11342  False                   nan   2500
# 15765  False                   nan   2500
#
#                                                   genres homepage     id  \
# 11342  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      nan  13209
# 15765  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      nan  13209
#
#          imdb_id original_language original_title  \
# 11342  tt0499537                fa        Offside
# 15765  tt0499537                fa        Offside
#
#                                                 overview  ... release_date  \
# 11342  Since women are banned from soccer matches, Ir...  ...   2006-05-26
# 15765  Since women are banned from soccer matches, Ir...  ...   2006-05-26
#
#       revenue runtime                        spoken_languages    status  \
# 11342     0.0    93.0  [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 15765     0.0    93.0  [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
#
# ...

# %%
filt110428 = (cleaned_df["id"] == "110428")
cleaned_df.loc[filt110428] #23534, checked
# Out:
#        adult belongs_to_collection   budget                         genres  \
# 4356   False                   nan  3512454  [{'id': 18, 'name': 'Drama'}]
# 23534  False                   nan  3512454  [{'id': 18, 'name': 'Drama'}]
#
#       homepage      id    imdb_id original_language        original_title  \
# 4356       nan  110428  tt2018086                fr  Camille Claudel 1915
# 23534      nan  110428  tt2018086                fr  Camille Claudel 1915
#
#                                                 overview  ... release_date  \
# 4356   Winter, 1915. Confined by her family to an asy...  ...   2013-03-13
# 23534  Winter, 1915. Confined by her family to an asy...  ...   2013-03-13
#
#         revenue runtime                           spoken_languages    status  \
# 4356   115860.0    95.0  [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 23534  115860.0    95.0  [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
#
# ...

# %%
filt4912 = (cleaned_df["id"] == "4912")
cleaned_df.loc[filt4912] #33826, checked
# Out:
#        adult belongs_to_collection    budget  \
# 5865   False                   nan  30000000
# 33826  False                   nan  30000000
#
#                                                   genres homepage    id  \
# 5865   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      nan  4912
# 33826  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      nan  4912
#
#          imdb_id original_language                   original_title  \
# 5865   tt0270288                en  Confessions of a Dangerous Mind
# 33826  tt0270288                en  Confessions of a Dangerous Mind
#
#                                                 overview  ... release_date  \
# 5865   Television made him famous, but his biggest hi...  ...   2002-12-30
# 33826  Television made him famous, but his biggest hi...  ...   2002-12-30
#
#           revenue runtime                          spoken_languages    status  \
# 5865   33013805.0   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %% [markdown]
# *-------------------RUN AFTER THIS------------------------*

# %%
cleaned_df.drop(index = [33743, 949, 2564, 12066, 20899, 44826, 44821, 838, 20843, 26625, 11342, 23534, 33826], inplace = True)

# %%
#cleaned all duplicate id rows
cleaned_df.id.value_counts()
# Out:
# id
# 862       1
# 40777     1
# 107308    1
# 16247     1
# 99904     1
#          ..
# 42191     1
# 190906    1
# 45615     1
# 38579     1
# 461257    1
# Name: count, Length: 45433, dtype: int64

# %%
cleaned_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                nan  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                nan  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                nan         0
# 45462  False                                                nan         0
# 45463  False                                                nan         0
# 45464  False                                                nan         0
# 45465  False                                                nan         0
#
#                                                   genres  \
# ...

# %%
cleaned_df["title"].value_counts() #TITLES HAVE DUPLICATES
# Out:
# title
# Cinderella              11
# Hamlet                   9
# Alice in Wonderland      9
# Les Misérables           8
# Beauty and the Beast     8
#                         ..
# Moloch                   1
# The Story Of My Life     1
# Crossworlds              1
# Centurion                1
# Queerama                 1
# Name: count, Length: 42278, dtype: int64

# %%
#replace String nan with np.nan values
cleaned_df.replace("nan", np.nan, inplace = True)

# %%
#find rows with NaN values in vote_average
filt_no_vote_average = cleaned_df.loc[(cleaned_df["vote_average"].isna())]
filt_no_vote_average
# Out:
#        adult                              belongs_to_collection budget  \
# 19729  False                                                NaN      0
# 29502  False  {'id': 122661, 'name': 'Mardock Scramble Colle...      0
# 35586  False                                                NaN      0
#
#                                                   genres  \
# 19729  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 29502  [{'id': 16, 'name': 'Animation'}, {'id': 878, ...
# 35586  [{'id': 10770, 'name': 'TV Movie'}, {'id': 28,...
#
#                             homepage      id    imdb_id original_language  \
# 19729                            NaN   82663  tt0113002                en
# 29502  http://m-scramble.jp/exhaust/  122662  tt2423504                ja
# 35586                            NaN  249260  tt2622826                en
#
#          original_title                                           overview  \
# ...

# %%
#drop these rows
cleaned_df.drop(index = [19729, 29502, 35586],inplace = True)

# %%
cleaned_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
#COPY cleaned dataframe so cleaned_df does not get changed and create sub copy
sub_cleaned_df = cleaned_df.rename(columns = {"id":"id","title":"title"})
sub_cleaned_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
#remove columns that have True value in column adult
cleaned_df.drop(cleaned_df[cleaned_df["adult"] == "True"].index, inplace = True)

# %%
cleaned_df[cleaned_df["original_title"] != cleaned_df["title"]][["original_title", "title"]]
# Out:
#                          original_title                      title
# 28           La Cité des Enfants Perdus  The City of Lost Children
# 29                            摇啊摇，摇到外婆桥             Shanghai Triad
# 32     Guillaumet, les ailes du courage           Wings of Courage
# 57                           Il postino                The Postman
# 58                     Le confessionnal           The Confessional
# ...                                 ...                        ...
# 45453                               Maa                        Mom
# 45455        San Michele aveva un gallo  St. Michael Had a Rooster
# 45461                           رگ خواب                     Subdue
# 45462               Siglo ng Pagluluwal        Century of Birthing
# 45464               Satana likuyushchiy           Satan Triumphant
#
# [11385 rows x 2 columns]

# %%
cleaned_df.drop(cleaned_df[cleaned_df["status"] != "Released"].index, inplace = True)

# %%
cleaned_df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
clean_sub_df = cleaned_df[["id", "title", "overview", "tagline","release_date", "runtime","vote_average", "vote_count", "original_language","original_title", "budget", "revenue", "genres", "spoken_languages", "popularity", "production_companies", "production_countries", "imdb_id", "belongs_to_collection", ]].copy()
clean_sub_df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# ...

# %%
clean_sub_df.dtypes
# Out:
# id                       object
# title                    object
# overview                 object
# tagline                  object
# release_date             object
# runtime                  object
# vote_average             object
# vote_count               object
# original_language        object
# original_title           object
# budget                   object
# revenue                  object
# genres                   object
# spoken_languages         object
# popularity               object
# production_companies     object
# production_countries     object
# imdb_id                  object
# belongs_to_collection    object
# dtype: object

# %%
clean_sub_df["id"] = clean_sub_df["id"].astype("int")
clean_sub_df["title"] = clean_sub_df["title"].astype("string")
clean_sub_df["runtime"] = clean_sub_df["runtime"].astype("float")
clean_sub_df["vote_average"] = clean_sub_df["vote_average"].astype("float")
clean_sub_df["vote_count"] = clean_sub_df["vote_count"].astype("float").astype("int")
clean_sub_df["budget"] = clean_sub_df["budget"].astype("float")

# %%
clean_sub_df.dtypes
# Out:
# id                                int32
# title                    string[python]
# overview                         object
# tagline                          object
# release_date                     object
# runtime                         float64
# vote_average                    float64
# vote_count                        int32
# original_language                object
# original_title                   object
# budget                          float64
# revenue                          object
# genres                           object
# spoken_languages                 object
# popularity                       object
# production_companies             object
# production_countries             object
# imdb_id                          object
# belongs_to_collection            object
# dtype: object

# %%
clean_sub_df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# ...

# %%
#enter direct string that has form of a list
def stringToList(string):
    return ast.literal_eval(string)


#splits list of dictionary with id and name as key into 2d list with id values in first list and name values in second list
def listOfDictToColumns(list):
        genres_id = []
        genre_names = []
        for i in list:
            for k, v in i.items():
                if k == "id":
                    genres_id.append(v)
                elif k == "name":
                    genre_names.append(v)
        return [genres_id, genre_names]

# %%
#error happens due to rerunning this cell, can only be run once
clean_sub_df.genres = clean_sub_df.genres.map(lambda x: stringToList(x))

# %%
clean_sub_df.genres = clean_sub_df.genres.map(lambda x: listOfDictToColumns(x))

# %%
def get_genre_names(list2d):
    return list2d[1]

# %%
clean_sub_df["genre_names"] = clean_sub_df["genres"].map(lambda x: get_genre_names(x))

# %%
clean_sub_df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# ...

# %%
clean_sub_df.to_csv("data/clean_movie_metadata.csv", index = False)
