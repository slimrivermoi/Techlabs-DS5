# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# %%
df = pd.read_csv("data/clean_movie_metadata.csv")

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44972  439050                       Subdue
# 44973  111109          Century of Birthing
# 44974   67758                     Betrayal
# 44975  227506             Satan Triumphant
# 44976  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 44972        Rising and falling between a man and woman.
# 44973  An artist struggles to finish his work while a...
# 44974  When one of her hits goes wrong, a professiona...
# 44975  In a small town live two brothers, one a minis...
# 44976  50 years after decriminalisation of homosexual...
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44972         Rising and falling between a man and woman          NaN
# 44973                                                NaN   2011-11-17
# 44974                             A deadly game of wits.   2003-08-01
# 44975                                                NaN   1917-10-21
# 44976                                                NaN   2017-06-09
#
#        runtime  vote_average  vote_count original_language  \
# 0         81.0           7.7      5415.0                en
# 1        104.0           6.9      2413.0                en
# 2        101.0           6.5        92.0                en
# 3        127.0           6.1        34.0                en
# 4        106.0           5.7       173.0                en
# ...        ...           ...         ...               ...
# 44972     90.0           4.0         1.0                fa
# 44973    360.0           9.0         3.0                tl
# 44974     90.0           3.8         6.0                en
# 44975     87.0           0.0         0.0                en
# 44976     75.0           0.0         0.0                en
#
#                     original_title    budget      revenue  \
# 0                        Toy Story  30000000  373554033.0
# 1                          Jumanji  65000000  262797249.0
# 2                 Grumpier Old Men         0          0.0
# 3                Waiting to Exhale  16000000   81452156.0
# 4      Father of the Bride Part II         0   76578911.0
# ...                            ...       ...          ...
# 44972                      رگ خواب         0          0.0
# 44973          Siglo ng Pagluluwal         0          0.0
# 44974                     Betrayal         0          0.0
# 44975          Satana likuyushchiy         0          0.0
# 44976                     Queerama         0          0.0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 44972  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 44973                      [{'id': 18, 'name': 'Drama'}]
# 44974  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 44975                                                 []
# 44976                                                 []
#
#                                         spoken_languages  popularity  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]   21.946943
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...   17.015539
# 2               [{'iso_639_1': 'en', 'name': 'English'}]   11.712900
# 3               [{'iso_639_1': 'en', 'name': 'English'}]    3.859495
# 4               [{'iso_639_1': 'en', 'name': 'English'}]    8.387519
# ...                                                  ...         ...
# 44972             [{'iso_639_1': 'fa', 'name': 'فارسی'}]    0.072051
# 44973                  [{'iso_639_1': 'tl', 'name': ''}]    0.178241
# 44974           [{'iso_639_1': 'en', 'name': 'English'}]    0.903007
# 44975                                                 []    0.003503
# 44976           [{'iso_639_1': 'en', 'name': 'English'}]    0.163015
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 44972                                                 []
# 44973             [{'name': 'Sine Olivia', 'id': 19653}]
# 44974  [{'name': 'American World Pictures', 'id': 6165}]
# 44975               [{'name': 'Yermoliev', 'id': 88753}]
# 44976                                                 []
#
#                                     production_countries    imdb_id  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...  tt0114709
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...  tt0113497
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...  tt0113228
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...  tt0114885
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...  tt0113041
# ...                                                  ...        ...
# 44972             [{'iso_3166_1': 'IR', 'name': 'Iran'}]  tt6209470
# 44973      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]  tt2028550
# 44974  [{'iso_3166_1': 'US', 'name': 'United States o...  tt0303758
# 44975           [{'iso_3166_1': 'RU', 'name': 'Russia'}]  tt0008536
# 44976   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  tt6980792
#
#                                    belongs_to_collection
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                    NaN
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                    NaN
# 4      {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                  ...
# 44972                                                NaN
# 44973                                                NaN
# 44974                                                NaN
# 44975                                                NaN
# 44976                                                NaN
#
# [44977 rows x 19 columns]

# %%
df["overview"] = df["overview"].astype("string")

# %%
df["overview"].dtype
# Out:
# string[python]

# %%
overview_series = df["overview"].loc[(df["overview"] != "NaN")]
overview_series.count()
# Out:
# 44057

# %%
# in general the formula looks something like this

# TF - Term frequency = (number of repetitions of words) / (number of words in sentence) ----- frequency of word in one text 
# IDF - Inverse Document Frequency = log( (number of texts) / (number of texts containing the word) ) ------ inverse frequency of word in all texts, the closer the value to zero is the more often the word appears in all texts
# weighted value = TF * IDF

#in basic terms the more often the words occur the lower the rating, filler words get a low rating this way and can be filtered 
#also contains zero values for every used word in all texts but not occurring in specific text

# %%
#initialize the vectorizer object
vectorizer = TfidfVectorizer() #possible keys stop_words = "english"
#this is where there will be created a vector for every value of column["overview"] which contains the "Term Frequency Inverse Document Frequency" for every word

vectors = vectorizer.fit_transform(overview_series.to_list())
#gets example vector for a movie and presents values
first_vector = vectors[10]
dfTEST = pd.DataFrame(first_vector.T.todense(), index= vectorizer.get_feature_names_out(), columns=["tfidf"]).sort_values(by=["tfidf"],ascending=False)

# %%
df.iloc[10]
# Out:
# id                                                                    9087
# title                                               The American President
# overview                 Widowed U.S. president Andrew Shepherd, one of...
# tagline                  Why can't the most powerful man in the world h...
# release_date                                                    1995-11-17
# runtime                                                              106.0
# vote_average                                                           6.5
# vote_count                                                           199.0
# original_language                                                       en
# original_title                                      The American President
# budget                                                            62000000
# revenue                                                        107879496.0
# genres                   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# spoken_languages                  [{'iso_639_1': 'en', 'name': 'English'}]
# popularity                                                        6.318445
# production_companies     [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# imdb_id                                                          tt0112346
# belongs_to_collection                                                  NaN
# Name: 10, dtype: object

# %%
dfTEST
# Out:
#                tfidf
# shepherd    0.396918
# decimate    0.247734
# lobbyist    0.243877
# covets      0.234953
# courting    0.232569
# ...              ...
# futuro      0.000000
# futurists   0.000000
# futuristic  0.000000
# futurist    0.000000
# ﬁve         0.000000
#
# [75685 rows x 1 columns]
